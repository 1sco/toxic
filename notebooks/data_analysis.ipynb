# %%
import pandas as pd
from pathlib import Path

# %%
data_path = Path('../data')
train_data = pd.read_csv(Path(data_path, 'train.csv'))
test_data = pd.read_csv(Path(data_path, 'test.csv'))

# %%
print(train_data.shape)
print(test_data.shape)
# Out:
# (159571, 8)
# (153164, 2)

# %%
test_data.head()
# Out:
#                  id                                       comment_text
# 0  00001cee341fdb12  Yo bitch Ja Rule is more succesful then you'll...
# 1  0000247867823ef7  == From RfC == \n\n The title is fine as it is...
# 2  00013b17ad220c46  " \n\n == Sources == \n\n * Zawe Ashton on Lap...
# 3  00017563c3f7919a  :If you have a look back at the source, the in...
# 4  00017695ad8997eb          I don't anonymously edit articles at all.

# %%
pd.set_option('max_colwidth', -1)
train_data.sample(20)
# Out:
#                       id  \
# 65298   aebe392ce7fb511e
# 61202   a3d26f97d4e11d4d
# 12405   20ea5e37520c073a
# 37506   642d67b5c1f9e434
# 79067   d39f2e95cbdf3f6e
# 92752   f8008effcf4b1d2e
# 39106   685cb61a4638e92f
# 67919   b5afc307a9f00e75
# 115043  6725f8ce5a4e7830
# 55959   95884e6e86bcc68b
# 63619   aa38b60fe8cc4126
# 102918  26d1c2bc566a996e
# 48127   809dd7ecd08211eb
# 140834  f1a5b6b7e063892b
# 93000   f8ab70a311e83356
# 49831   85401a980c0f24bf
# 99377   138f6133488ab801
# 92825   f8332636cd9d2cd3
# 9446    191159a947781b7c
# 34892   5d34f1fb2cd63845
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      comment_text  \
# 65298   Trivia \n\nThis article once had a trivia section, which I thought was useful for a film article. I think trivia sections are valid content for an encyclopoedia if labelled so and we should re-install the one for this page. Comments?
# 61202   "\n\n...and censoring certain types of information is too often an attempt to ""sweeten"" the well, which is no less insidious that ""poisoning"" it.   "
# 12405   Edit: well, with boundary conditions, G will be more complicated. But for example, with Neumann boundary conditions, it is clear to see that the remaining surface integral should not be negative (by comparing with the wikipedia page for Helmholtz decomposition). It should have the opposite sign. The other part of the surface integral should also be the negative of what is written.
# 37506   You Should create a account good work on the Miami Dolphins article '' | watz sup
# 79067   Ialsoagree, The article is now deleted and you  have nither allowed time nor respected the  'hang on  tag'. I respectfully  suggest   that either you are a fraction  less speedy  with  your actions, or that  your new page patrol  principles be rewiewed by  more experience editors or admins.
# 92752   I am impressed with the psychoanalytic detective work you have done going down the rabbit hole of my contribution history and perhaps flattered but I am afraid your conclusions are entirely erroneous, Paul...  /talk/
# 39106   Try debating on the talk page, first.
# 67919   Now \n\nI still think you are doo doo.\n\nYes, doo doo indeed.
# 115043  "\n\n Thanxs for the support! \n\nThank you for supporting the pic I nominated.  One thing though...I'm kind of befuddled regarding the stated age on your user page.  Your 17, but in med school?!?  Wow, do I feel stupid!   Cont@ct  =D"
# 55959   OK, the first human I have found. I want to contact someone at Wikipedia or Wikimedia, or whatever the organization is, and resolve this issue. If you are not in that position, then give me the contact details of someone who is.
# 63619   Work for clean-up,section biography added,rest later or tomorrow.It will take time,I think.Thanks for your assistance.
# 102918  Well i don't know what or unfortanetly i know where i got it, its from here:
# 48127   Hmm, yeah, Lucas sarcastically joking about it is possible. I'm assuming good faith on the author's comments since I never heard the commentary myself (very rarely will I ever watch a movie again with commentary on), and it is problematic that he didn't specify who was saying it in the commentary, a producer, an actor, etc. I still laughed at reading this though and thought it'd be a shame if it was excised for good, assuming it's factual!
# 140834  The Six Feet Under logo could do with a transparent background.
# 93000   Thank you for experimenting with the page Witzelsucht on Wikipedia. Your test worked, and has been reverted or removed. Please use the sandbox for any other tests you want to do. Take a look at the welcome page if you would like to learn more about contributing to our encyclopedia.  -
# 49831   Organization \n\nI am doing some wiki cleaning to argnize this better.  We have relilgion in differnet sections.  Have Sullivan in different sections.  Chinese wife in different sections.  Love him or hate him...let's try to follow a MECE format.
# 99377   " \n""In 2000, it was awarded Best Album at the Q Awards."" I presume this year is wrong since it is two years before the album was released.\nFixed.  (Hit  \n\nCritical reviews\nYou use ""compliment"" three times in the first couple of sentences and four times in total. Consider finding alternatives.\nI made some changes. Don't know if there alright.  (Hit  \n\nCommercial performance\n8x Platinum, 5x Platinum and 4x Platinum. See above.\nI think I got it.  (Hit  \n""more stronger than its predecessor,"" You don't need ""more"" and ""stronger"" together.\nGot it.  (Hit  \n\nCredits\nWikilink anyone not previously linked.\nAdded links.  (Hit  \n\nA bit to do, but nothing substantial, so I'll put it on hold for now.   "
# 92825   "\n\n Edit request on 6 December 2012 \n\nThe film is ""hit"" not ""superhit"" according to BoxOfficeIndia.com:\nhttp://www.boxofficeindia.com/cpages.php?pageName=earnings\n\nSo in the third paragraph it should be "" Box Office India declared the film a ""hit"" in India""\n\n139.190.140.12  \n\n139.190.140.12  "
# 9446    "\n\n""millions were killed on their way to the west"" is an example of German home-made history. The total number of German victims wasn't ""millions"" and many of the victims died of infections. The German government was responsible for the too late and poorly organised evacuation (""Flucht""). \n\nThe Germans created many myths about the expulsion. Now a German demands academic treatment. Yes, yes, yes! But the academic treatment has been done. There are thousands of pages of published documents. \n\n""Instead of this it has become a platform where everybody seems to be allowed to post his own history regardless how wrong and unsystematic it may ever be."" Exactly and you are one of the ill informed and emotional posters.\n \n\nrestored the deleted contri ackoz  "
# 34892   That is a useful correction, but was the number of settings that had to be searched in the bomy and bombes still 17,576?
#
#         toxic  severe_toxic  obscene  threat  insult  identity_hate
# 65298   0      0             0        0       0       0
# 61202   0      0             0        0       0       0
# 12405   0      0             0        0       0       0
# 37506   0      0             0        0       0       0
# 79067   0      0             0        0       0       0
# 92752   0      0             0        0       0       0
# 39106   0      0             0        0       0       0
# 67919   0      0             0        0       0       0
# 115043  0      0             0        0       0       0
# 55959   0      0             0        0       0       0
# 63619   0      0             0        0       0       0
# 102918  0      0             0        0       0       0
# 48127   0      0             0        0       0       0
# 140834  0      0             0        0       0       0
# 93000   0      0             0        0       0       0
# 49831   0      0             0        0       0       0
# 99377   0      0             0        0       0       0
# 92825   0      0             0        0       0       0
# 9446    0      0             0        0       0       0
# 34892   0      0             0        0       0       0
